# %% [markdown]
# # pyQUEIJU: run QE from jupyter
#
# **pyQUEIJU: QUantum Espresso Interface on JUpyter**
#
# In this example we use pyQUEIJU to obtain and plot the graphene bands.
#
# In my server the QE binaries are placed within the $PATH. But if yours are not, you can inform the correct path at the object initialization.

# %%
# we'll need these to plot the bands
import numpy as np
import matplotlib.pyplot as plt

# add pyqueiju module folder to the pythonpath
# or save the module within your pythonpath to avoid these lines
import sys
sys.path.append('./pyqueiju')

# import the module itself
from pyqueiju import queiju

# %% [markdown]
# ## How to use it
#
# - To create an instance call:
#
# > `relax = queiju(relax_in, qe_path)`
#
# or
#
# > `relax = queiju(relax_in)`
#
# where `relax_in` is the string with the QE input data (see below in the examples) and `qe_path` is the path to the QE binaries. If the binaries are on $PATH, we can ommit `qe_path=""` as in the second line above. Here we are calling this instance **relax**, but use an appropriate name for the type of calculation you are calling (relax, scf, nscf, bands, ...)
#
# - To run, call the `run` method informing the proper binary:
#
# > `relax.run("pw.x")`
#
# - To see the output, either print to screen or save to an external file as
#
# > `print(relax.out)`
#
# > `relax.saveoutput('relax.out')`
#
# - A list of files created or modified by the QE run is available at
#
# > `print(relax.files)`
#
# ### Creating scripts to go from relax to scf, etc...
#
# Check the example below. It is much easier to build python scripts using the structure above instead of going to a terminal or running bash scripts.
#
# ### For more information
#
# Check the gitlab webpage and our **TO DO LIST** at the board.

# %% [markdown]
# ## 1 - Relaxation

# %%
#########################
# DEFINE the input file #
#########################
relax_in = """
&CONTROL
    calculation='vc-relax'
    prefix='graphene'
    restart_mode='from_scratch'
    outdir='./outdir'
    pseudo_dir='/home/gerson/pseudo'
/
&SYSTEM
    ibrav = 4, a = 2.460, c= 20,
    nat = 2, ntyp = 1,
    ecutwfc = 40.0 ,
    ecutrho = 400.0 ,
    occupations = 'smearing', degauss = 0.0001, smearing = 'marzari-vanderbilt',
    assume_isolated = '2D'
/
&ELECTRONS
    conv_thr = 1.0d-8,
    mixing_beta = 0.3,
/
&IONS
/
&CELL
    cell_dofree = '2Dxy'
/
ATOMIC_SPECIES
C 12.0107 C.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
C 0.000000000 0.000000000 0.250000000
C 0.333333333 0.666666667 0.250000000
K_POINTS automatic
12 12 1 0 0 0
"""

# %%
# initializes the object and runs the code
relax = queiju(relax_in)
print("It took ", relax.run("pw.x"), " seconds")
# Out:
# It took  82.04520288505591  seconds

# %%
# prints the full output file
print(relax.out)
# if you want to save the output to a file, run
#relax.saveoutput('relax.out')
# Out:
#      Program PWSCF v.6.3 starts on 18Aug2020 at 16:31: 2
#
#      This program is part of the open-source Quantum ESPRESSO suite
#      for quantum simulation of materials; please cite
#          "P. Giannozzi et al., J. Phys.:Condens. Matter 21 395502 (2009);
#          "P. Giannozzi et al., J. Phys.:Condens. Matter 29 465901 (2017);
#           URL http://www.quantum-espresso.org",
#      in publications or presentations arising from this work. More details at
#      http://www.quantum-espresso.org/quote
#
#      Parallel version (MPI), running on     1 processors
#
#      MPI processes distributed on     1 nodes
#      Waiting for input...
#      Reading input from standard input
#
#      Current dimensions of program PWSCF are:
#      Max number of different atomic species (ntypx) = 10
#      Max number of k-points (npk) =  40000
#      Max angular momentum in pseudopotentials (lmaxx) =  3
#                file C.pbe-n-kjpaw_psl.1.0.0.UPF: wavefunction(s)  2S 2P renormalized
#
#      Subspace diagonalization in iterative solution of the eigenvalue problem:
#      a serial algorithm will be used
#
#
#      G-vector sticks info
#      --------------------
#      sticks:   dense  smooth     PW     G-vecs:    dense   smooth      PW
#      Sum         595     241     85                95599    24261    4575
#
#
#
#      bravais-lattice index     =            4
#      lattice parameter (alat)  =       4.6487  a.u.
#      unit-cell volume          =     707.3387 (a.u.)^3
#      number of atoms/cell      =            2
#      number of atomic types    =            1
#      number of electrons       =         8.00
#      number of Kohn-Sham states=            8
#      kinetic-energy cutoff     =      40.0000  Ry
#      charge density cutoff     =     400.0000  Ry
#      convergence threshold     =      1.0E-08
#      mixing beta               =       0.3000
#      number of iterations used =            8  plain     mixing
#      Exchange-correlation      = SLA PW PBX PBC ( 1  4  3  4 0 0)
#      nstep                     =           50
#
#
#      celldm(1)=   4.648726  celldm(2)=   0.000000  celldm(3)=   8.130081
#      celldm(4)=   0.000000  celldm(5)=   0.000000  celldm(6)=   0.000000
#
#      crystal axes: (cart. coord. in units of alat)
#                a(1) = (   1.000000   0.000000   0.000000 )
#                a(2) = (  -0.500000   0.866025   0.000000 )
#                a(3) = (   0.000000   0.000000   8.130081 )
#
#      reciprocal axes: (cart. coord. in units 2 pi/alat)
#                b(1) = (  1.000000  0.577350 -0.000000 )
#                b(2) = (  0.000000  1.154701  0.000000 )
#                b(3) = (  0.000000 -0.000000  0.123000 )
#
#
#      PseudoPot. # 1 for C  read from file:
#      /home/gerson/pseudo/C.pbe-n-kjpaw_psl.1.0.0.UPF
#      MD5 check sum: 5f16ad9a65e90284d1d834d4ab3b0f7d
#      Pseudo is Projector augmented-wave + core cor, Zval =  4.0
#      Generated using "atomic" code by A. Dal Corso v.6.3
#      Shape of augmentation charge: PSQ
#      Using radial grid of 1073 points,  4 beta functions with:
#                 l(1) =   0
#                 l(2) =   0
#                 l(3) =   1
#                 l(4) =   1
#      Q(r) pseudized with 0 coefficients
#
#
#      atomic species   valence    mass     pseudopotential
#         C              4.00    12.01070     C ( 1.00)
#
#      12 Sym. Ops. (no inversion) found ( 6 have fractional translation)
#           (note: 12 additional sym.ops. were found but ignored
#            their fractional translations are incommensurate with FFT grid)
#
#
#    Cartesian axes
#
#      site n.     atom                  positions (alat units)
#          1           C   tau(   1) = (   0.0000000   0.0000000   2.0325203  )
#          2           C   tau(   2) = (  -0.0000000   0.5773503   2.0325203  )
#
#      number of k points=    19  Marzari-Vanderbilt smearing, width (Ry)=  0.0001
#                        cart. coord. in units 2pi/alat
#         k(    1) = (   0.0000000   0.0000000   0.0000000), wk =   0.0138889
#         k(    2) = (   0.0000000   0.0962250   0.0000000), wk =   0.0833333
#         k(    3) = (   0.0000000   0.1924501   0.0000000), wk =   0.0833333
#         k(    4) = (   0.0000000   0.2886751   0.0000000), wk =   0.0833333
#         k(    5) = (   0.0000000   0.3849002   0.0000000), wk =   0.0833333
#         k(    6) = (   0.0000000   0.4811252   0.0000000), wk =   0.0833333
#         k(    7) = (   0.0000000  -0.5773503   0.0000000), wk =   0.0416667
#         k(    8) = (   0.0833333   0.1443376   0.0000000), wk =   0.0833333
#         k(    9) = (   0.0833333   0.2405626   0.0000000), wk =   0.1666667
#         k(   10) = (   0.0833333   0.3367877   0.0000000), wk =   0.1666667
#         k(   11) = (   0.0833333   0.4330127   0.0000000), wk =   0.1666667
#         k(   12) = (   0.0833333   0.5292377   0.0000000), wk =   0.1666667
#         k(   13) = (   0.1666667   0.2886751   0.0000000), wk =   0.0833333
#         k(   14) = (   0.1666667   0.3849002   0.0000000), wk =   0.1666667
#         k(   15) = (   0.1666667   0.4811252   0.0000000), wk =   0.1666667
#         k(   16) = (   0.1666667   0.5773503   0.0000000), wk =   0.0833333
#         k(   17) = (   0.2500000   0.4330127   0.0000000), wk =   0.0833333
#         k(   18) = (   0.2500000   0.5292377   0.0000000), wk =   0.1666667
#         k(   19) = (   0.3333333   0.5773503   0.0000000), wk =   0.0277778
#
#      Dense  grid:    95599 G-vectors     FFT dimensions: (  30,  30, 243)
#
#      Smooth grid:    24261 G-vectors     FFT dimensions: (  20,  20, 160)
#
#      Estimated max dynamical RAM per process >     135.95 MB
#  ----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D
#   The code is running with the 2D cutoff
#   Please refer to:
#   Sohier, T., Calandra, M., & Mauri, F. (2017),
#   Density functional perturbation theory for gated two-dimensional heterostructures:
#   Theoretical developments and application to flexural phonons in graphene.
#   Physical Review B, 96(7), 75448. https://doi.org/10.1103/PhysRevB.96.075448
#  ----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D
#
#      Check: negative/imaginary core charge=   -0.000002    0.000000
#
#      Initial potential from superposition of free atoms
#      Check: negative starting charge=   -0.000106
#
#      starting charge    7.99992, renormalised to    8.00000
#
#      negative rho (up, down):  1.058E-04 0.000E+00
#      Starting wfcs are    8 randomized atomic wfcs
#      Checking if some PAW data can be deallocated...
#
#      total cpu time spent up to now is        3.1 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  1.00E-02,  avg # of iterations =  5.3
#
#      negative rho (up, down):  1.029E-04 0.000E+00
#
#      total cpu time spent up to now is        4.3 secs
#
#      total energy              =     -36.90806172 Ry
#      Harris-Foulkes estimate   =     -36.97874779 Ry
#      estimated scf accuracy    <       0.20471188 Ry
#
#      iteration #  2     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  2.56E-03,  avg # of iterations =  1.0
#
#      negative rho (up, down):  2.666E-04 0.000E+00
#
#      total cpu time spent up to now is        5.2 secs
#
#      total energy              =     -36.87338375 Ry
#      Harris-Foulkes estimate   =     -36.91398442 Ry
#      estimated scf accuracy    <       0.06925352 Ry
#
#      iteration #  3     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  8.66E-04,  avg # of iterations =  6.8
#
#      negative rho (up, down):  2.515E-04 0.000E+00
#
#      total cpu time spent up to now is        6.4 secs
#
#      total energy              =     -36.88642351 Ry
#      Harris-Foulkes estimate   =     -36.88604563 Ry
#      estimated scf accuracy    <       0.00156863 Ry
#
#      iteration #  4     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  1.96E-05,  avg # of iterations =  4.6
#
#      negative rho (up, down):  2.199E-04 0.000E+00
#
#      total cpu time spent up to now is        7.6 secs
#
#      total energy              =     -36.88506318 Ry
#      Harris-Foulkes estimate   =     -36.88790956 Ry
#      estimated scf accuracy    <       0.00437517 Ry
#
#      iteration #  5     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  1.96E-05,  avg # of iterations =  2.9
#
#      negative rho (up, down):  1.781E-04 0.000E+00
#
#      total cpu time spent up to now is        8.6 secs
#
#      total energy              =     -36.88582227 Ry
#      Harris-Foulkes estimate   =     -36.88582238 Ry
#      estimated scf accuracy    <       0.00000230 Ry
#
#      iteration #  6     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  2.87E-08,  avg # of iterations =  3.3
#
#      negative rho (up, down):  1.544E-04 0.000E+00
#
#      total cpu time spent up to now is        9.7 secs
#
#      total energy              =     -36.88582381 Ry
#      Harris-Foulkes estimate   =     -36.88582354 Ry
#      estimated scf accuracy    <       0.00000049 Ry
#
#      iteration #  7     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  6.12E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.409E-04 0.000E+00
#
#      total cpu time spent up to now is       10.6 secs
#
#      total energy              =     -36.88582368 Ry
#      Harris-Foulkes estimate   =     -36.88582386 Ry
#      estimated scf accuracy    <       0.00000032 Ry
#
#      iteration #  8     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  3.95E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.256E-04 0.000E+00
#
#      total cpu time spent up to now is       11.5 secs
#
#      End of self-consistent calculation
#
#           k = 0.0000 0.0000 0.0000 (  3053 PWs)   bands (ev):
#
#    -23.8079 -11.8918  -7.2698  -7.2698  -1.0362  -0.3613   0.4085   0.8961
#
#           k = 0.0000 0.0962 0.0000 (  3034 PWs)   bands (ev):
#
#    -23.6433 -11.6947  -7.9226  -7.6109  -0.8120  -0.1338   0.6364   1.1228
#
#           k = 0.0000 0.1925 0.0000 (  3042 PWs)   bands (ev):
#
#    -23.1511 -11.1084  -9.5671  -8.4098  -0.1393   0.5478   1.3200   1.8014
#
#           k = 0.0000 0.2887 0.0000 (  3030 PWs)   bands (ev):
#
#    -22.3372 -11.6743 -10.1524  -9.2963   0.9797   1.6731   2.4579   2.8620
#
#           k = 0.0000 0.3849 0.0000 (  3024 PWs)   bands (ev):
#
#    -21.2136 -13.8873 -10.0352  -8.8769   0.7206   2.5347   3.2851   3.5667
#
#           k = 0.0000 0.4811 0.0000 (  3034 PWs)   bands (ev):
#
#    -19.8110 -15.9979 -10.5113  -7.4455  -1.4291   3.3170   4.5560   5.3058
#
#           k = 0.0000-0.5774 0.0000 (  3036 PWs)   bands (ev):
#
#    -18.5350 -17.5179 -10.6749  -6.5952  -2.5351   3.2392   6.8777   7.0225
#
#           k = 0.0833 0.1443 0.0000 (  3043 PWs)   bands (ev):
#
#    -23.3149 -11.3029  -8.9602  -8.2939  -0.3633   0.3209   1.0923   1.5756
#
#           k = 0.0833 0.2406 0.0000 (  3029 PWs)   bands (ev):
#
#    -22.6618 -10.6767 -10.5305  -9.2991   0.5333   1.2276   2.0039   2.4773
#
#           k = 0.0833 0.3368 0.0000 (  3026 PWs)   bands (ev):
#
#    -21.6930 -12.7589 -10.1913  -9.4083   1.7385   1.8740   2.6068   3.3684
#
#           k = 0.0833 0.4330 0.0000 (  3023 PWs)   bands (ev):
#
#    -20.4270 -14.8917 -10.8302  -8.0205  -0.4746   3.6358   4.1698   4.3958
#
#           k = 0.0833 0.5292 0.0000 (  3021 PWs)   bands (ev):
#
#    -18.9386 -16.8445 -11.1606  -6.7029  -2.2559   3.9798   5.8624   6.6034
#
#           k = 0.1667 0.2887 0.0000 (  3017 PWs)   bands (ev):
#
#    -21.8538 -12.0104 -10.6709  -9.5880   1.6526   2.2022   2.3564   3.1437
#
#           k = 0.1667 0.3849 0.0000 (  3024 PWs)   bands (ev):
#
#    -20.7412 -13.7457 -11.7328  -8.3278   0.2412   3.2107   3.9211   4.7359
#
#           k = 0.1667 0.4811 0.0000 (  3015 PWs)   bands (ev):
#
#    -19.3586 -15.6668 -12.3109  -6.8923  -1.6842   5.1834   5.8622   5.8971
#
#           k = 0.1667 0.5774 0.0000 (  2996 PWs)   bands (ev):
#
#    -18.1126 -17.1146 -12.4964  -5.9935  -2.7602   5.7943   7.4477   7.6359
#
#           k = 0.2500 0.4330 0.0000 (  3009 PWs)   bands (ev):
#
#    -19.5073 -14.7816 -13.2272  -6.9771  -1.3829   4.9710   5.5857   6.5508
#
#           k = 0.2500 0.5292 0.0000 (  2995 PWs)   bands (ev):
#
#    -18.0768 -16.2120 -13.9375  -5.5826  -2.9131   6.6635   7.0843   8.0624
#
#           k = 0.3333 0.5774 0.0000 (  2967 PWs)   bands (ev):
#
#    -16.8517 -16.8517 -14.8453  -4.2183  -4.2183   6.4079   8.7054   8.7054
#
#      the Fermi energy is    -4.2181 ev
#
# !    total energy              =     -36.88582372 Ry
#      Harris-Foulkes estimate   =     -36.88582372 Ry
#      estimated scf accuracy    <          1.8E-09 Ry
#
#      total all-electron energy =      -152.414018 Ry
#
#      The total energy is the sum of the following terms:
#
#      one-electron contribution =    -359.09323334 Ry
#      hartree contribution      =     180.42965907 Ry
#      xc contribution           =      -9.28434657 Ry
#      ewald contribution        =     163.39636289 Ry
#      one-center paw contrib.   =     -12.33426486 Ry
#      smearing contrib. (-TS)   =      -0.00000091 Ry
#
#      convergence has been achieved in   8 iterations
#
#      negative rho (up, down):  1.256E-04 0.000E+00
#
#      Forces acting on atoms (cartesian axes, Ry/au):
#
#      atom    1 type  1   force =     0.00000000    0.00000000    0.00000000
#      atom    2 type  1   force =     0.00000000    0.00000000    0.00000000
#
#      Total force =     0.000000     Total SCF correction =     0.000008
#
#
#      Computing stress (Cartesian axis) and pressure
#
#
#      negative rho (up, down):  1.256E-04 0.000E+00
#           total   stress  (Ry/bohr**3)                   (kbar)     P=    2.79
#    0.00003351   0.00000000   0.00000000          4.93      0.00      0.00
#    0.00000000   0.00003351   0.00000000          0.00      4.93      0.00
#    0.00000000   0.00000000  -0.00001013          0.00      0.00     -1.49
#
#
#      BFGS Geometry Optimization
#
#      number of scf cycles    =   1
#      number of bfgs steps    =   0
#
#      enthalpy new            =     -36.8858237240 Ry
#
#      new trust radius        =       0.0044557532 bohr
#      new conv_thr            =       0.0000000100 Ry
#
#      new unit-cell volume =    708.52429 a.u.^3 (   104.99247 Ang^3 )
#      density =      0.37992 g/cm^3
#
# CELL_PARAMETERS (alat=  4.64872629)
#    1.000837679   0.000000000   0.000000000
#   -0.500418839   0.866750855   0.000000000
#    0.000000000   0.000000000   8.130081301
#
# ATOMIC_POSITIONS (crystal)
# C        0.000000000   0.000000000   0.250000000
# C        0.333333333   0.666666667   0.250000000
#
#
#
#      Writing output data file graphene.save/
#      Check: negative starting charge=   -0.000106
#      NEW-OLD atomic charge density approx. for the potential
#
#      Check: negative/imaginary core charge=   -0.000002    0.000000
#      Check: negative starting charge=   -0.000107
#
#      negative rho (up, down):  1.268E-04 0.000E+00
#      extrapolated charge    8.01339, renormalised to    8.00000
#
#      total cpu time spent up to now is       20.8 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  1.00E-06,  avg # of iterations =  6.4
#
#      negative rho (up, down):  1.260E-04 0.000E+00
#
#      total cpu time spent up to now is       22.1 secs
#
#      total energy              =     -36.88576181 Ry
#      Harris-Foulkes estimate   =     -36.29872338 Ry
#      estimated scf accuracy    <       0.00005613 Ry
#
#      iteration #  2     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  7.02E-07,  avg # of iterations =  6.8
#
#      negative rho (up, down):  1.264E-04 0.000E+00
#
#      total cpu time spent up to now is       23.4 secs
#
#      total energy              =     -36.88585780 Ry
#      Harris-Foulkes estimate   =     -36.88586024 Ry
#      estimated scf accuracy    <       0.00000851 Ry
#
#      iteration #  3     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  1.06E-07,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.267E-04 0.000E+00
#
#      total cpu time spent up to now is       24.3 secs
#
#      total energy              =     -36.88585616 Ry
#      Harris-Foulkes estimate   =     -36.88585800 Ry
#      estimated scf accuracy    <       0.00000390 Ry
#
#      iteration #  4     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  4.88E-08,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.269E-04 0.000E+00
#
#      total cpu time spent up to now is       25.1 secs
#
#      total energy              =     -36.88585626 Ry
#      Harris-Foulkes estimate   =     -36.88585643 Ry
#      estimated scf accuracy    <       0.00000057 Ry
#
#      iteration #  5     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  7.11E-09,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.271E-04 0.000E+00
#
#      total cpu time spent up to now is       26.0 secs
#
#      total energy              =     -36.88585623 Ry
#      Harris-Foulkes estimate   =     -36.88585628 Ry
#      estimated scf accuracy    <       0.00000023 Ry
#
#      iteration #  6     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  2.82E-09,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.272E-04 0.000E+00
#
#      total cpu time spent up to now is       26.8 secs
#
#      total energy              =     -36.88585615 Ry
#      Harris-Foulkes estimate   =     -36.88585623 Ry
#      estimated scf accuracy    <       0.00000012 Ry
#
#      iteration #  7     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  1.46E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.273E-04 0.000E+00
#
#      total cpu time spent up to now is       27.7 secs
#
#      End of self-consistent calculation
#
#           k = 0.0000 0.0000 0.0000 (  3053 PWs)   bands (ev):
#
#    -23.7951 -11.8822  -7.2782  -7.2782  -1.0354  -0.3603   0.4099   0.8971
#
#           k =-0.0000 0.0961 0.0000 (  3034 PWs)   bands (ev):
#
#    -23.6307 -11.6854  -7.9304  -7.6183  -0.8115  -0.1331   0.6374   1.1233
#
#           k =-0.0000 0.1923 0.0000 (  3042 PWs)   bands (ev):
#
#    -23.1392 -11.1004  -9.5730  -8.4153  -0.1400   0.5473   1.3198   1.8007
#
#           k =-0.0000 0.2884 0.0000 (  3030 PWs)   bands (ev):
#
#    -22.3266 -11.6775 -10.1464  -9.2997   0.9772   1.6704   2.4559   2.8550
#
#           k =-0.0000 0.3846 0.0000 (  3024 PWs)   bands (ev):
#
#    -21.2048 -13.8873 -10.0370  -8.8737   0.7032   2.5294   3.2797   3.5365
#
#           k =-0.0000 0.4807 0.0000 (  3034 PWs)   bands (ev):
#
#    -19.8047 -15.9945 -10.5121  -7.4457  -1.4408   3.2853   4.5470   5.2968
#
#           k = 0.0000-0.5769 0.0000 (  3036 PWs)   bands (ev):
#
#    -18.5337 -17.5092 -10.6753  -6.5976  -2.5436   3.2070   6.8648   7.0094
#
#           k = 0.0833 0.1442 0.0000 (  3043 PWs)   bands (ev):
#
#    -23.3028 -11.2945  -8.9670  -8.2996  -0.3636   0.3207   1.0925   1.5753
#
#           k = 0.0833 0.2404 0.0000 (  3029 PWs)   bands (ev):
#
#    -22.6507 -10.6816 -10.5237  -9.3026   0.5315   1.2259   2.0026   2.4754
#
#           k = 0.0833 0.3365 0.0000 (  3026 PWs)   bands (ev):
#
#    -21.6834 -12.7609 -10.1930  -9.4039   1.7182   1.8699   2.6023   3.3648
#
#           k = 0.0833 0.4327 0.0000 (  3023 PWs)   bands (ev):
#
#    -20.4194 -14.8904 -10.8307  -8.0192  -0.4892   3.6279   4.1384   4.3884
#
#           k = 0.0833 0.5288 0.0000 (  3021 PWs)   bands (ev):
#
#    -18.9344 -16.8392 -11.1605  -6.7049  -2.2656   3.9469   5.8513   6.5917
#
#           k = 0.1665 0.2884 0.0000 (  3017 PWs)   bands (ev):
#
#    -21.8439 -12.0144 -10.6711  -9.5832   1.6488   2.1797   2.3527   3.1405
#
#           k = 0.1665 0.3846 0.0000 (  3024 PWs)   bands (ev):
#
#    -20.7331 -13.7472 -11.7313  -8.3258   0.2238   3.2044   3.9145   4.7299
#
#           k = 0.1665 0.4807 0.0000 (  3015 PWs)   bands (ev):
#
#    -19.3530 -15.6646 -12.3088  -6.8937  -1.6965   5.1732   5.8517   5.8627
#
#           k = 0.1665 0.5769 0.0000 (  2996 PWs)   bands (ev):
#
#    -18.1117 -17.1075 -12.4942  -5.9972  -2.7694   5.7593   7.3781   7.4333
#
#           k = 0.2498 0.4327 0.0000 (  3009 PWs)   bands (ev):
#
#    -19.5013 -14.7832 -13.2217  -6.9781  -1.3965   4.9615   5.5757   6.5415
#
#           k = 0.2498 0.5288 0.0000 (  2995 PWs)   bands (ev):
#
#    -18.0739 -16.2103 -13.9312  -5.5870  -2.9231   6.6511   7.0705   8.3972
#
#           k = 0.3331 0.5769 0.0000 (  2967 PWs)   bands (ev):
#
#    -16.8517 -16.8517 -14.8341  -4.2257  -4.2257   6.3969   8.6811   8.6811
#
#      the Fermi energy is    -4.2255 ev
#
# !    total energy              =     -36.88585618 Ry
#      Harris-Foulkes estimate   =     -36.88585618 Ry
#      estimated scf accuracy    <          1.0E-09 Ry
#
#      total all-electron energy =      -152.414051 Ry
#
#      The total energy is the sum of the following terms:
#
#      one-electron contribution =    -358.48449996 Ry
#      hartree contribution      =     180.12349022 Ry
#      xc contribution           =      -9.28057172 Ry
#      ewald contribution        =     163.08982627 Ry
#      one-center paw contrib.   =     -12.33410009 Ry
#      smearing contrib. (-TS)   =      -0.00000091 Ry
#
#      convergence has been achieved in   7 iterations
#
#      negative rho (up, down):  1.273E-04 0.000E+00
#
#      Forces acting on atoms (cartesian axes, Ry/au):
#
#      atom    1 type  1   force =     0.00000000    0.00000000    0.00000000
#      atom    2 type  1   force =     0.00000000    0.00000000    0.00000000
#
#      Total force =     0.000000     Total SCF correction =     0.000000
#
#
#      Computing stress (Cartesian axis) and pressure
#
#
#      negative rho (up, down):  1.273E-04 0.000E+00
#           total   stress  (Ry/bohr**3)                   (kbar)     P=    1.59
#    0.00002128   0.00000000   0.00000000          3.13      0.00      0.00
#    0.00000000   0.00002128   0.00000000          0.00      3.13      0.00
#    0.00000000   0.00000000  -0.00001017          0.00      0.00     -1.50
#
#
#      number of scf cycles    =   2
#      number of bfgs steps    =   1
#
#      enthalpy old            =     -36.8858237240 Ry
#      enthalpy new            =     -36.8858561773 Ry
#
#      CASE: enthalpy_new < enthalpy_old
#
#      new trust radius        =       0.0049013285 bohr
#      new conv_thr            =            1.0E-10 Ry
#
#      new unit-cell volume =    709.82953 a.u.^3 (   105.18588 Ang^3 )
#      density =      0.37922 g/cm^3
#
# CELL_PARAMETERS (alat=  4.64872629)
#    1.001759125   0.000000000   0.000000000
#   -0.500879563   0.867548851   0.000000000
#    0.000000000   0.000000000   8.130081301
#
# ATOMIC_POSITIONS (crystal)
# C        0.000000000   0.000000000   0.250000000
# C        0.333333333   0.666666667   0.250000000
#
#
#
#      Writing output data file graphene.save/
#      Check: negative starting charge=   -0.000107
#      NEW-OLD atomic charge density approx. for the potential
#
#      Check: negative/imaginary core charge=   -0.000002    0.000000
#      Check: negative starting charge=   -0.000108
#
#      negative rho (up, down):  1.286E-04 0.000E+00
#      extrapolated charge    8.01471, renormalised to    8.00000
#
#      total cpu time spent up to now is       37.1 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  1.00E-06,  avg # of iterations =  6.1
#
#      negative rho (up, down):  1.277E-04 0.000E+00
#
#      total cpu time spent up to now is       38.4 secs
#
#      total energy              =     -36.88576105 Ry
#      Harris-Foulkes estimate   =     -36.24182956 Ry
#      estimated scf accuracy    <       0.00006802 Ry
#
#      iteration #  2     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  8.50E-07,  avg # of iterations =  6.7
#
#      negative rho (up, down):  1.281E-04 0.000E+00
#
#      total cpu time spent up to now is       39.7 secs
#
#      total energy              =     -36.88587713 Ry
#      Harris-Foulkes estimate   =     -36.88588009 Ry
#      estimated scf accuracy    <       0.00001029 Ry
#
#      iteration #  3     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  1.29E-07,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.285E-04 0.000E+00
#
#      total cpu time spent up to now is       40.5 secs
#
#      total energy              =     -36.88587520 Ry
#      Harris-Foulkes estimate   =     -36.88587737 Ry
#      estimated scf accuracy    <       0.00000470 Ry
#
#      iteration #  4     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  5.88E-08,  avg # of iterations =  1.7
#
#      negative rho (up, down):  1.287E-04 0.000E+00
#
#      total cpu time spent up to now is       41.4 secs
#
#      total energy              =     -36.88587527 Ry
#      Harris-Foulkes estimate   =     -36.88587552 Ry
#      estimated scf accuracy    <       0.00000075 Ry
#
#      iteration #  5     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  9.36E-09,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.290E-04 0.000E+00
#
#      total cpu time spent up to now is       42.3 secs
#
#      total energy              =     -36.88587524 Ry
#      Harris-Foulkes estimate   =     -36.88587530 Ry
#      estimated scf accuracy    <       0.00000028 Ry
#
#      iteration #  6     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  3.44E-09,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.291E-04 0.000E+00
#
#      total cpu time spent up to now is       43.1 secs
#
#      total energy              =     -36.88587514 Ry
#      Harris-Foulkes estimate   =     -36.88587524 Ry
#      estimated scf accuracy    <       0.00000015 Ry
#
#      iteration #  7     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  1.89E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.291E-04 0.000E+00
#
#      total cpu time spent up to now is       44.0 secs
#
#      total energy              =     -36.88587518 Ry
#      Harris-Foulkes estimate   =     -36.88587518 Ry
#      estimated scf accuracy    <          1.4E-09 Ry
#
#      iteration #  8     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  1.78E-11,  avg # of iterations =  1.8
#
#      negative rho (up, down):  1.291E-04 0.000E+00
#
#      total cpu time spent up to now is       44.9 secs
#
#      total energy              =     -36.88587518 Ry
#      Harris-Foulkes estimate   =     -36.88587518 Ry
#      estimated scf accuracy    <          1.0E-09 Ry
#
#      iteration #  9     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  1.31E-11,  avg # of iterations =  1.9
#
#      negative rho (up, down):  1.292E-04 0.000E+00
#
#      total cpu time spent up to now is       45.8 secs
#
#      End of self-consistent calculation
#
#           k = 0.0000 0.0000 0.0000 (  3053 PWs)   bands (ev):
#
#    -23.7812 -11.8717  -7.2876  -7.2876  -1.0352  -0.3609   0.4093   0.8966
#
#           k =-0.0000 0.0961 0.0000 (  3034 PWs)   bands (ev):
#
#    -23.6171 -11.6754  -7.9391  -7.6267  -0.8118  -0.1342   0.6364   1.1224
#
#           k =-0.0000 0.1921 0.0000 (  3042 PWs)   bands (ev):
#
#    -23.1264 -11.0918  -9.5797  -8.4215  -0.1414   0.5450   1.3176   1.7985
#
#           k =-0.0000 0.2882 0.0000 (  3030 PWs)   bands (ev):
#
#    -22.3151 -11.6812 -10.1400  -9.3036   0.9737   1.6659   2.4515   2.8448
#
#           k =-0.0000 0.3842 0.0000 (  3024 PWs)   bands (ev):
#
#    -21.1953 -13.8876 -10.0391  -8.8703   0.6839   2.5229   3.2721   3.5030
#
#           k =-0.0000 0.4803 0.0000 (  3034 PWs)   bands (ev):
#
#    -19.7979 -15.9910 -10.5131  -7.4459  -1.4538   3.2503   4.5366   5.2854
#
#           k = 0.0000-0.5763 0.0000 (  3036 PWs)   bands (ev):
#
#    -18.5324 -17.4998 -10.6760  -6.6005  -2.5531   3.1714   6.8500   6.9948
#
#           k = 0.0832 0.1441 0.0000 (  3043 PWs)   bands (ev):
#
#    -23.2897 -11.2854  -8.9747  -8.3061  -0.3647   0.3189   1.0906   1.5736
#
#           k = 0.0832 0.2401 0.0000 (  3029 PWs)   bands (ev):
#
#    -22.6387 -10.6871 -10.5164  -9.3066   0.5289   1.2223   1.9991   2.4719
#
#           k = 0.0832 0.3362 0.0000 (  3026 PWs)   bands (ev):
#
#    -21.6730 -12.7632 -10.1950  -9.3992   1.6959   1.8648   2.5956   3.3588
#
#           k = 0.0832 0.4323 0.0000 (  3023 PWs)   bands (ev):
#
#    -20.4113 -14.8891 -10.8314  -8.0180  -0.5054   3.6185   4.1038   4.3788
#
#           k = 0.0832 0.5283 0.0000 (  3021 PWs)   bands (ev):
#
#    -18.9300 -16.8334 -11.1605  -6.7072  -2.2764   3.9107   5.8386   6.5776
#
#           k = 0.1664 0.2882 0.0000 (  3017 PWs)   bands (ev):
#
#    -21.8333 -12.0191 -10.6715  -9.5781   1.6441   2.1550   2.3470   3.1349
#
#           k = 0.1664 0.3842 0.0000 (  3024 PWs)   bands (ev):
#
#    -20.7243 -13.7490 -11.7298  -8.3237   0.2047   3.1968   3.9058   4.7213
#
#           k = 0.1664 0.4803 0.0000 (  3015 PWs)   bands (ev):
#
#    -19.3470 -15.6625 -12.3067  -6.8952  -1.7101   5.1614   5.8249   5.8390
#
#           k = 0.1664 0.5763 0.0000 (  2996 PWs)   bands (ev):
#
#    -18.1107 -17.0998 -12.4919  -6.0014  -2.7797   5.7206   7.3611   7.4170
#
#           k = 0.2496 0.4323 0.0000 (  3009 PWs)   bands (ev):
#
#    -19.4949 -14.7852 -13.2158  -6.9794  -1.4117   4.9506   5.5636   6.5295
#
#           k = 0.2496 0.5283 0.0000 (  2995 PWs)   bands (ev):
#
#    -18.0709 -16.2087 -13.9244  -5.5919  -2.9342   6.6372   7.0548   8.3811
#
#           k = 0.3327 0.5763 0.0000 (  2967 PWs)   bands (ev):
#
#    -16.8518 -16.8518 -14.8221  -4.2340  -4.2340   6.3847   8.6540   8.6540
#
#      the Fermi energy is    -4.2338 ev
#
# !    total energy              =     -36.88587518 Ry
#      Harris-Foulkes estimate   =     -36.88587518 Ry
#      estimated scf accuracy    <          8.3E-11 Ry
#
#      total all-electron energy =      -152.414070 Ry
#
#      The total energy is the sum of the following terms:
#
#      one-electron contribution =    -357.81678019 Ry
#      hartree contribution      =     179.78770541 Ry
#      xc contribution           =      -9.27643317 Ry
#      ewald contribution        =     162.75355576 Ry
#      one-center paw contrib.   =     -12.33392207 Ry
#      smearing contrib. (-TS)   =      -0.00000091 Ry
#
#      convergence has been achieved in   9 iterations
#
#      negative rho (up, down):  1.292E-04 0.000E+00
#
#      Forces acting on atoms (cartesian axes, Ry/au):
#
#      atom    1 type  1   force =     0.00000000    0.00000000   -0.00000000
#      atom    2 type  1   force =    -0.00000000    0.00000000   -0.00000000
#
#      Total force =     0.000000     Total SCF correction =     0.000000
#
#
#      Computing stress (Cartesian axis) and pressure
#
#
#      negative rho (up, down):  1.292E-04 0.000E+00
#           total   stress  (Ry/bohr**3)                   (kbar)     P=    0.28
#    0.00000789  -0.00000000   0.00000000          1.16     -0.00      0.00
#    0.00000000   0.00000789   0.00000000          0.00      1.16      0.00
#    0.00000000   0.00000000  -0.00001009          0.00      0.00     -1.48
#
#
#      number of scf cycles    =   3
#      number of bfgs steps    =   2
#
#      enthalpy old            =     -36.8858561773 Ry
#      enthalpy new            =     -36.8858751768 Ry
#
#      CASE: enthalpy_new < enthalpy_old
#
#      new trust radius        =       0.0028926695 bohr
#      new conv_thr            =            1.0E-10 Ry
#
#      new unit-cell volume =    710.60042 a.u.^3 (   105.30012 Ang^3 )
#      density =      0.37881 g/cm^3
#
# CELL_PARAMETERS (alat=  4.64872629)
#    1.002302945   0.000000000   0.000000000
#   -0.501151472   0.868019813   0.000000000
#    0.000000000   0.000000000   8.130081301
#
# ATOMIC_POSITIONS (crystal)
# C        0.000000000   0.000000000   0.250000000
# C        0.333333333   0.666666667   0.250000000
#
#
#
#      Writing output data file graphene.save/
#      Check: negative starting charge=   -0.000108
#      NEW-OLD atomic charge density approx. for the potential
#
#      Check: negative/imaginary core charge=   -0.000002    0.000000
#      Check: negative starting charge=   -0.000108
#
#      negative rho (up, down):  1.299E-04 0.000E+00
#      extrapolated charge    8.00868, renormalised to    8.00000
#
#      total cpu time spent up to now is       55.1 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  1.00E-06,  avg # of iterations =  5.2
#
#      negative rho (up, down):  1.294E-04 0.000E+00
#
#      total cpu time spent up to now is       56.3 secs
#
#      total energy              =     -36.88583896 Ry
#      Harris-Foulkes estimate   =     -36.50646006 Ry
#      estimated scf accuracy    <       0.00002346 Ry
#
#      iteration #  2     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  2.93E-07,  avg # of iterations =  5.1
#
#      negative rho (up, down):  1.297E-04 0.000E+00
#
#      total cpu time spent up to now is       57.5 secs
#
#      total energy              =     -36.88587889 Ry
#      Harris-Foulkes estimate   =     -36.88587989 Ry
#      estimated scf accuracy    <       0.00000351 Ry
#
#      iteration #  3     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  4.39E-08,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.299E-04 0.000E+00
#
#      total cpu time spent up to now is       58.4 secs
#
#      total energy              =     -36.88587825 Ry
#      Harris-Foulkes estimate   =     -36.88587897 Ry
#      estimated scf accuracy    <       0.00000161 Ry
#
#      iteration #  4     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  2.01E-08,  avg # of iterations =  1.5
#
#      negative rho (up, down):  1.300E-04 0.000E+00
#
#      total cpu time spent up to now is       59.2 secs
#
#      total energy              =     -36.88587824 Ry
#      Harris-Foulkes estimate   =     -36.88587835 Ry
#      estimated scf accuracy    <       0.00000029 Ry
#
#      iteration #  5     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  3.60E-09,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.302E-04 0.000E+00
#
#      total cpu time spent up to now is       60.1 secs
#
#      total energy              =     -36.88587825 Ry
#      Harris-Foulkes estimate   =     -36.88587825 Ry
#      estimated scf accuracy    <       0.00000007 Ry
#
#      iteration #  6     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  8.55E-10,  avg # of iterations =  1.0
#
#      negative rho (up, down):  1.302E-04 0.000E+00
#
#      total cpu time spent up to now is       60.9 secs
#
#      total energy              =     -36.88587821 Ry
#      Harris-Foulkes estimate   =     -36.88587825 Ry
#      estimated scf accuracy    <       0.00000006 Ry
#
#      iteration #  7     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  7.08E-10,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.303E-04 0.000E+00
#
#      total cpu time spent up to now is       61.9 secs
#
#      total energy              =     -36.88587823 Ry
#      Harris-Foulkes estimate   =     -36.88587823 Ry
#      estimated scf accuracy    <          2.5E-10 Ry
#
#      iteration #  8     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  3.13E-12,  avg # of iterations =  2.1
#
#      negative rho (up, down):  1.303E-04 0.000E+00
#
#      total cpu time spent up to now is       62.8 secs
#
#      End of self-consistent calculation
#
#           k = 0.0000 0.0000 0.0000 (  3053 PWs)   bands (ev):
#
#    -23.7728 -11.8654  -7.2929  -7.2929  -1.0351  -0.3612   0.4090   0.8963
#
#           k =-0.0000 0.0960 0.0000 (  3034 PWs)   bands (ev):
#
#    -23.6088 -11.6694  -7.9440  -7.6314  -0.8118  -0.1347   0.6358   1.1219
#
#           k =-0.0000 0.1920 0.0000 (  3042 PWs)   bands (ev):
#
#    -23.1187 -11.0865  -9.5835  -8.4249  -0.1422   0.5437   1.3163   1.7972
#
#           k =-0.0000 0.2880 0.0000 (  3030 PWs)   bands (ev):
#
#    -22.3081 -11.6832 -10.1360  -9.3057   0.9717   1.6633   2.4489   2.8381
#
#           k =-0.0000 0.3840 0.0000 (  3024 PWs)   bands (ev):
#
#    -21.1894 -13.8875 -10.0401  -8.8681   0.6727   2.5191   3.2677   3.4834
#
#           k =-0.0000 0.4800 0.0000 (  3034 PWs)   bands (ev):
#
#    -19.7938 -15.9886 -10.5135  -7.4459  -1.4613   3.2299   4.5305   5.2787
#
#           k = 0.0000-0.5760 0.0000 (  3036 PWs)   bands (ev):
#
#    -18.5314 -17.4940 -10.6761  -6.6020  -2.5586   3.1507   6.8414   6.9863
#
#           k = 0.0831 0.1440 0.0000 (  3043 PWs)   bands (ev):
#
#    -23.2818 -11.2799  -8.9791  -8.3097  -0.3652   0.3178   1.0896   1.5725
#
#           k = 0.0831 0.2400 0.0000 (  3029 PWs)   bands (ev):
#
#    -22.6314 -10.6902 -10.5119  -9.3087   0.5274   1.2202   1.9970   2.4698
#
#           k = 0.0831 0.3360 0.0000 (  3026 PWs)   bands (ev):
#
#    -21.6667 -12.7644 -10.1960  -9.3963   1.6828   1.8619   2.5918   3.3550
#
#           k = 0.0831 0.4320 0.0000 (  3023 PWs)   bands (ev):
#
#    -20.4063 -14.8881 -10.8316  -8.0170  -0.5148   3.6130   4.0836   4.3731
#
#           k = 0.0831 0.5280 0.0000 (  3021 PWs)   bands (ev):
#
#    -18.9273 -16.8298 -11.1603  -6.7084  -2.2826   3.8895   5.8312   6.5693
#
#           k = 0.1663 0.2880 0.0000 (  3017 PWs)   bands (ev):
#
#    -21.8268 -12.0216 -10.6715  -9.5749   1.6414   2.1406   2.3436   3.1315
#
#           k = 0.1663 0.3840 0.0000 (  3024 PWs)   bands (ev):
#
#    -20.7190 -13.7499 -11.7287  -8.3223   0.1936   3.1924   3.9007   4.7162
#
#           k = 0.1663 0.4800 0.0000 (  3015 PWs)   bands (ev):
#
#    -19.3433 -15.6610 -12.3053  -6.8960  -1.7179   5.1546   5.8028   5.8315
#
#           k = 0.1663 0.5760 0.0000 (  2996 PWs)   bands (ev):
#
#    -18.1100 -17.0951 -12.4903  -6.0037  -2.7856   5.6979   7.3513   7.4074
#
#           k = 0.2494 0.4320 0.0000 (  3009 PWs)   bands (ev):
#
#    -19.4909 -14.7862 -13.2122  -6.9799  -1.4204   4.9442   5.5565   6.5223
#
#           k = 0.2494 0.5280 0.0000 (  2995 PWs)   bands (ev):
#
#    -18.0690 -16.2075 -13.9202  -5.5946  -2.9406   6.6292   7.0455   8.3713
#
#           k = 0.3326 0.5760 0.0000 (  2967 PWs)   bands (ev):
#
#    -16.8517 -16.8517 -14.8148  -4.2387  -4.2387   6.3776   8.6382   8.6382
#
#      the Fermi energy is    -4.2385 ev
#
# !    total energy              =     -36.88587823 Ry
#      Harris-Foulkes estimate   =     -36.88587823 Ry
#      estimated scf accuracy    <          9.2E-11 Ry
#
#      total all-electron energy =      -152.414073 Ry
#
#      The total energy is the sum of the following terms:
#
#      one-electron contribution =    -357.42353559 Ry
#      hartree contribution      =     179.58991811 Ry
#      xc contribution           =      -9.27398904 Ry
#      ewald contribution        =     162.55554613 Ry
#      one-center paw contrib.   =     -12.33381691 Ry
#      smearing contrib. (-TS)   =      -0.00000091 Ry
#
#      convergence has been achieved in   8 iterations
#
#      negative rho (up, down):  1.303E-04 0.000E+00
#
#      Forces acting on atoms (cartesian axes, Ry/au):
#
#      atom    1 type  1   force =    -0.00000000    0.00000000   -0.00000000
#      atom    2 type  1   force =     0.00000000   -0.00000000   -0.00000000
#
#      Total force =     0.000000     Total SCF correction =     0.000000
#
#
#      Computing stress (Cartesian axis) and pressure
#
#
#      negative rho (up, down):  1.303E-04 0.000E+00
#           total   stress  (Ry/bohr**3)                   (kbar)     P=   -0.49
#    0.00000005  -0.00000000  -0.00000000          0.01     -0.00     -0.00
#   -0.00000000   0.00000005  -0.00000000         -0.00      0.01     -0.00
#    0.00000000   0.00000000  -0.00001012          0.00      0.00     -1.49
#
#
#      bfgs converged in   4 scf cycles and   3 bfgs steps
#      (criteria: energy <  1.0E-04 Ry, force <  1.0E-03Ry/Bohr, cell <  5.0E-01kbar)
#
#      End of BFGS Geometry Optimization
#
#      Final enthalpy =     -36.8858782258 Ry
# Begin final coordinates
#      new unit-cell volume =    710.60042 a.u.^3 (   105.30012 Ang^3 )
#      density =      0.37881 g/cm^3
#
# CELL_PARAMETERS (alat=  4.64872629)
#    1.002302945   0.000000000   0.000000000
#   -0.501151472   0.868019813   0.000000000
#    0.000000000   0.000000000   8.130081301
#
# ATOMIC_POSITIONS (crystal)
# C        0.000000000   0.000000000   0.250000000
# C        0.333333333   0.666666667   0.250000000
# End final coordinates
#
#
#
#      Writing output data file graphene.save/
#
#      A final scf calculation at the relaxed structure.
#      The G-vectors are recalculated for the final unit cell
#      Results may differ from those at the preceding step.
#
#      G-vector sticks info
#      --------------------
#      sticks:   dense  smooth     PW     G-vecs:    dense   smooth      PW
#      Sum         595     241     85                95959    24345    4587
#
#
#
#      bravais-lattice index     =            4
#      lattice parameter (alat)  =       4.6487  a.u.
#      unit-cell volume          =     710.6004 (a.u.)^3
#      number of atoms/cell      =            2
#      number of atomic types    =            1
#      number of electrons       =         8.00
#      number of Kohn-Sham states=            8
#      kinetic-energy cutoff     =      40.0000  Ry
#      charge density cutoff     =     400.0000  Ry
#      convergence threshold     =      1.0E-10
#      mixing beta               =       0.3000
#      number of iterations used =            8  plain     mixing
#      Exchange-correlation      = SLA PW PBX PBC ( 1  4  3  4 0 0)
#
#      celldm(1)=   4.648726  celldm(2)=   0.000000  celldm(3)=   8.130081
#      celldm(4)=   0.000000  celldm(5)=   0.000000  celldm(6)=   0.000000
#
#      crystal axes: (cart. coord. in units of alat)
#                a(1) = (   1.002303   0.000000   0.000000 )
#                a(2) = (  -0.501151   0.868020   0.000000 )
#                a(3) = (   0.000000   0.000000   8.130081 )
#
#      reciprocal axes: (cart. coord. in units 2 pi/alat)
#                b(1) = (  0.997702  0.576024 -0.000000 )
#                b(2) = ( -0.000000  1.152047  0.000000 )
#                b(3) = (  0.000000 -0.000000  0.123000 )
#
#
#      PseudoPot. # 1 for C  read from file:
#      /home/gerson/pseudo/C.pbe-n-kjpaw_psl.1.0.0.UPF
#      MD5 check sum: 5f16ad9a65e90284d1d834d4ab3b0f7d
#      Pseudo is Projector augmented-wave + core cor, Zval =  4.0
#      Generated using "atomic" code by A. Dal Corso v.6.3
#      Shape of augmentation charge: PSQ
#      Using radial grid of 1073 points,  4 beta functions with:
#                 l(1) =   0
#                 l(2) =   0
#                 l(3) =   1
#                 l(4) =   1
#      Q(r) pseudized with 0 coefficients
#
#
#      atomic species   valence    mass     pseudopotential
#         C              4.00    12.01070     C ( 1.00)
#
#      12 Sym. Ops. (no inversion) found ( 6 have fractional translation)
#           (note: 12 additional sym.ops. were found but ignored
#            their fractional translations are incommensurate with FFT grid)
#
#
#    Cartesian axes
#
#      site n.     atom                  positions (alat units)
#          1           C   tau(   1) = (   0.0000000   0.0000000   2.0325203  )
#          2           C   tau(   2) = (  -0.0000000   0.5786799   2.0325203  )
#
#      number of k points=    19  Marzari-Vanderbilt smearing, width (Ry)=  0.0001
#                        cart. coord. in units 2pi/alat
#         k(    1) = (   0.0000000   0.0000000   0.0000000), wk =   0.0138889
#         k(    2) = (  -0.0000000   0.0960040   0.0000000), wk =   0.0833333
#         k(    3) = (  -0.0000000   0.1920079   0.0000000), wk =   0.0833333
#         k(    4) = (  -0.0000000   0.2880119   0.0000000), wk =   0.0833333
#         k(    5) = (  -0.0000000   0.3840158   0.0000000), wk =   0.0833333
#         k(    6) = (  -0.0000000   0.4800198   0.0000000), wk =   0.0833333
#         k(    7) = (   0.0000000  -0.5760237   0.0000000), wk =   0.0416667
#         k(    8) = (   0.0831419   0.1440059   0.0000000), wk =   0.0833333
#         k(    9) = (   0.0831419   0.2400099   0.0000000), wk =   0.1666667
#         k(   10) = (   0.0831419   0.3360138   0.0000000), wk =   0.1666667
#         k(   11) = (   0.0831419   0.4320178   0.0000000), wk =   0.1666667
#         k(   12) = (   0.0831419   0.5280217   0.0000000), wk =   0.1666667
#         k(   13) = (   0.1662837   0.2880119   0.0000000), wk =   0.0833333
#         k(   14) = (   0.1662837   0.3840158   0.0000000), wk =   0.1666667
#         k(   15) = (   0.1662837   0.4800198   0.0000000), wk =   0.1666667
#         k(   16) = (   0.1662837   0.5760237   0.0000000), wk =   0.0833333
#         k(   17) = (   0.2494256   0.4320178   0.0000000), wk =   0.0833333
#         k(   18) = (   0.2494256   0.5280217   0.0000000), wk =   0.1666667
#         k(   19) = (   0.3325674   0.5760237   0.0000000), wk =   0.0277778
#
#      Dense  grid:    95959 G-vectors     FFT dimensions: (  30,  30, 243)
#
#      Smooth grid:    24345 G-vectors     FFT dimensions: (  20,  20, 160)
#
#      Estimated max dynamical RAM per process >     137.14 MB
#  ----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D
#   The code is running with the 2D cutoff
#   Please refer to:
#   Sohier, T., Calandra, M., & Mauri, F. (2017),
#   Density functional perturbation theory for gated two-dimensional heterostructures:
#   Theoretical developments and application to flexural phonons in graphene.
#   Physical Review B, 96(7), 75448. https://doi.org/10.1103/PhysRevB.96.075448
#  ----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D
#
#      Check: negative/imaginary core charge=   -0.000002    0.000000
#
#      Initial potential from superposition of free atoms
#      Check: negative starting charge=   -0.000106
#
#      starting charge    7.99992, renormalised to    8.00000
#
#      negative rho (up, down):  1.061E-04 0.000E+00
#      Starting wfcs are    8 randomized atomic wfcs
#      Checking if some PAW data can be deallocated...
#
#      total cpu time spent up to now is       69.6 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      c_bands:  1 eigenvalues not converged
#      c_bands:  1 eigenvalues not converged
#      c_bands:  1 eigenvalues not converged
#      c_bands:  1 eigenvalues not converged
#      c_bands:  1 eigenvalues not converged
#      ethr =  1.00E-06,  avg # of iterations = 17.7
#
#      negative rho (up, down):  1.095E-04 0.000E+00
#
#      total cpu time spent up to now is       72.1 secs
#
#      total energy              =     -36.90749140 Ry
#      Harris-Foulkes estimate   =     -36.97770614 Ry
#      estimated scf accuracy    <       0.20289174 Ry
#
#      iteration #  2     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  2.54E-03,  avg # of iterations =  1.1
#
#      negative rho (up, down):  2.599E-04 0.000E+00
#
#      total cpu time spent up to now is       73.0 secs
#
#      total energy              =     -36.87527361 Ry
#      Harris-Foulkes estimate   =     -36.91334779 Ry
#      estimated scf accuracy    <       0.06633244 Ry
#
#      iteration #  3     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  8.29E-04,  avg # of iterations =  4.8
#
#      negative rho (up, down):  2.692E-04 0.000E+00
#
#      total cpu time spent up to now is       74.0 secs
#
#      total energy              =     -36.88583960 Ry
#      Harris-Foulkes estimate   =     -36.88595039 Ry
#      estimated scf accuracy    <       0.00124659 Ry
#
#      iteration #  4     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  1.56E-05,  avg # of iterations =  4.0
#
#      negative rho (up, down):  2.209E-04 0.000E+00
#
#      total cpu time spent up to now is       75.1 secs
#
#      total energy              =     -36.88584291 Ry
#      Harris-Foulkes estimate   =     -36.88613025 Ry
#      estimated scf accuracy    <       0.00048092 Ry
#
#      iteration #  5     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  6.01E-06,  avg # of iterations =  2.6
#
#      negative rho (up, down):  1.805E-04 0.000E+00
#
#      total cpu time spent up to now is       76.1 secs
#
#      total energy              =     -36.88591245 Ry
#      Harris-Foulkes estimate   =     -36.88591355 Ry
#      estimated scf accuracy    <       0.00000362 Ry
#
#      iteration #  6     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  4.53E-08,  avg # of iterations =  2.4
#
#      negative rho (up, down):  1.548E-04 0.000E+00
#
#      total cpu time spent up to now is       77.1 secs
#
#      total energy              =     -36.88591391 Ry
#      Harris-Foulkes estimate   =     -36.88591404 Ry
#      estimated scf accuracy    <       0.00000056 Ry
#
#      iteration #  7     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  6.94E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.409E-04 0.000E+00
#
#      total cpu time spent up to now is       78.0 secs
#
#      total energy              =     -36.88591400 Ry
#      Harris-Foulkes estimate   =     -36.88591398 Ry
#      estimated scf accuracy    <       0.00000001 Ry
#
#      iteration #  8     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  1.34E-10,  avg # of iterations =  2.1
#
#      negative rho (up, down):  1.335E-04 0.000E+00
#
#      total cpu time spent up to now is       78.9 secs
#
#      total energy              =     -36.88591402 Ry
#      Harris-Foulkes estimate   =     -36.88591400 Ry
#      estimated scf accuracy    <          5.4E-09 Ry
#
#      iteration #  9     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  6.72E-11,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.258E-04 0.000E+00
#
#      total cpu time spent up to now is       79.8 secs
#
#      End of self-consistent calculation
#
#           k = 0.0000 0.0000 0.0000 (  3053 PWs)   bands (ev):
#
#    -23.7729 -11.8655  -7.2930  -7.2930  -1.0348  -0.3605   0.4102   0.8973
#
#           k =-0.0000 0.0960 0.0000 (  3048 PWs)   bands (ev):
#
#    -23.6089 -11.6695  -7.9443  -7.6318  -0.8116  -0.1340   0.6370   1.1228
#
#           k =-0.0000 0.1920 0.0000 (  3046 PWs)   bands (ev):
#
#    -23.1188 -11.0866  -9.5836  -8.4250  -0.1420   0.5444   1.3175   1.7982
#
#           k =-0.0000 0.2880 0.0000 (  3046 PWs)   bands (ev):
#
#    -22.3082 -11.6834 -10.1361  -9.3061   0.9720   1.6639   2.4501   2.8385
#
#           k =-0.0000 0.3840 0.0000 (  3042 PWs)   bands (ev):
#
#    -21.1895 -13.8879 -10.0402  -8.8682   0.6725   2.5193   3.2684   3.4833
#
#           k =-0.0000 0.4800 0.0000 (  3050 PWs)   bands (ev):
#
#    -19.7939 -15.9888 -10.5138  -7.4461  -1.4614   3.2298   4.5307   5.2793
#
#           k = 0.0000-0.5760 0.0000 (  3052 PWs)   bands (ev):
#
#    -18.5315 -17.4941 -10.6765  -6.6020  -2.5587   3.1505   6.8417   6.9864
#
#           k = 0.0831 0.1440 0.0000 (  3051 PWs)   bands (ev):
#
#    -23.2819 -11.2799  -8.9792  -8.3100  -0.3649   0.3185   1.0908   1.5735
#
#           k = 0.0831 0.2400 0.0000 (  3043 PWs)   bands (ev):
#
#    -22.6315 -10.6904 -10.5120  -9.3090   0.5276   1.2209   1.9983   2.4707
#
#           k = 0.0831 0.3360 0.0000 (  3028 PWs)   bands (ev):
#
#    -21.6667 -12.7645 -10.1961  -9.3963   1.6827   1.8621   2.5925   3.3563
#
#           k = 0.0831 0.4320 0.0000 (  3039 PWs)   bands (ev):
#
#    -20.4064 -14.8884 -10.8317  -8.0172  -0.5149   3.6132   4.0836   4.3738
#
#           k = 0.0831 0.5280 0.0000 (  3037 PWs)   bands (ev):
#
#    -18.9274 -16.8300 -11.1605  -6.7086  -2.2827   3.8893   5.8315   6.5698
#
#           k = 0.1663 0.2880 0.0000 (  3031 PWs)   bands (ev):
#
#    -21.8269 -12.0217 -10.6717  -9.5750   1.6417   2.1404   2.3443   3.1328
#
#           k = 0.1663 0.3840 0.0000 (  3041 PWs)   bands (ev):
#
#    -20.7191 -13.7500 -11.7290  -8.3223   0.1934   3.1926   3.9013   4.7175
#
#           k = 0.1663 0.4800 0.0000 (  3039 PWs)   bands (ev):
#
#    -19.3434 -15.6612 -12.3056  -6.8961  -1.7181   5.1548   5.8026   5.8320
#
#           k = 0.1663 0.5760 0.0000 (  3000 PWs)   bands (ev):
#
#    -18.1101 -17.0953 -12.4904  -6.0038  -2.7857   5.6978   7.3513   7.4076
#
#           k = 0.2494 0.4320 0.0000 (  3029 PWs)   bands (ev):
#
#    -19.4910 -14.7863 -13.2124  -6.9801  -1.4206   4.9444   5.5570   6.5236
#
#           k = 0.2494 0.5280 0.0000 (  3011 PWs)   bands (ev):
#
#    -18.0691 -16.2077 -13.9204  -5.5947  -2.9407   6.6291   7.0457   7.9630
#
#           k = 0.3326 0.5760 0.0000 (  3009 PWs)   bands (ev):
#
#    -16.8519 -16.8519 -14.8152  -4.2389  -4.2389   6.3775   8.6380   8.6380
#
#      the Fermi energy is    -4.2387 ev
#
# !    total energy              =     -36.88591404 Ry
#      Harris-Foulkes estimate   =     -36.88591402 Ry
#      estimated scf accuracy    <          1.2E-11 Ry
#
#      total all-electron energy =      -152.414108 Ry
#
#      The total energy is the sum of the following terms:
#
#      one-electron contribution =    -357.42367621 Ry
#      hartree contribution      =     179.59001895 Ry
#      xc contribution           =      -9.27399337 Ry
#      ewald contribution        =     162.55554613 Ry
#      one-center paw contrib.   =     -12.33380862 Ry
#      smearing contrib. (-TS)   =      -0.00000091 Ry
#
#      convergence has been achieved in   9 iterations
#
#      negative rho (up, down):  1.258E-04 0.000E+00
#
#      Forces acting on atoms (cartesian axes, Ry/au):
#
#      atom    1 type  1   force =     0.00000000    0.00000000   -0.00000000
#      atom    2 type  1   force =     0.00000000    0.00000000   -0.00000000
#
#      Total force =     0.000000     Total SCF correction =     0.000003
#
#
#      Computing stress (Cartesian axis) and pressure
#
#
#      negative rho (up, down):  1.258E-04 0.000E+00
#           total   stress  (Ry/bohr**3)                   (kbar)     P=   -0.43
#    0.00000058   0.00000000   0.00000000          0.09      0.00      0.00
#    0.00000000   0.00000058   0.00000000          0.00      0.09      0.00
#    0.00000000   0.00000000  -0.00000984          0.00      0.00     -1.45
#
#
#      Writing output data file graphene.save/
#
#      init_run     :      6.94s CPU      3.69s WALL (       2 calls)
#      electrons    :    233.44s CPU     41.93s WALL (       5 calls)
#      update_pot   :     10.65s CPU      9.53s WALL (       3 calls)
#      forces       :     12.44s CPU      7.45s WALL (       5 calls)
#      stress       :     42.02s CPU     18.03s WALL (       5 calls)
#
#      Called by init_run:
#      wfcinit      :      3.44s CPU      0.50s WALL (       2 calls)
#      potinit      :      1.11s CPU      1.12s WALL (       2 calls)
#      hinit0       :      1.93s CPU      1.93s WALL (       2 calls)
#
#      Called by electrons:
#      c_bands      :    170.81s CPU     25.10s WALL (      41 calls)
#      sum_band     :     46.51s CPU      8.46s WALL (      41 calls)
#      v_of_rho     :      4.99s CPU      4.06s WALL (      46 calls)
#      newd         :      2.40s CPU      1.21s WALL (      46 calls)
#      PAW_pot      :      3.33s CPU      2.84s WALL (      49 calls)
#      mix_rho      :      5.91s CPU      0.91s WALL (      41 calls)
#
#      Called by c_bands:
#      init_us_2    :      9.16s CPU      1.38s WALL (    1843 calls)
#      cegterg      :    155.62s CPU     22.84s WALL (     779 calls)
#
#      Called by sum_band:
#      sum_band:bec :      0.02s CPU      0.00s WALL (     836 calls)
#      addusdens    :     14.41s CPU      3.34s WALL (      41 calls)
#
#      Called by *egterg:
#      h_psi        :    139.44s CPU     20.59s WALL (    3266 calls)
#      s_psi        :      0.81s CPU      0.11s WALL (    3266 calls)
#      g_psi        :      4.38s CPU      0.61s WALL (    2449 calls)
#      cdiaghg      :      4.32s CPU      0.61s WALL (    3171 calls)
#
#      Called by h_psi:
#      h_psi:pot    :    137.64s CPU     20.34s WALL (    3266 calls)
#      h_psi:calbec :      3.14s CPU      0.48s WALL (    3266 calls)
#      vloc_psi     :    133.38s CPU     19.70s WALL (    3266 calls)
#      add_vuspsi   :      0.99s CPU      0.14s WALL (    3266 calls)
#
#      General routines
#      calbec       :      4.37s CPU      0.66s WALL (    4577 calls)
#      fft          :     12.64s CPU      3.82s WALL (     721 calls)
#      ffts         :      0.08s CPU      0.04s WALL (      87 calls)
#      fftw         :    112.64s CPU     16.85s WALL (   41746 calls)
#      interpolate  :      0.22s CPU      0.22s WALL (      46 calls)
#
#      Parallel routines
#
#      PWSCF        :  5m 7.50s CPU     1m21.25s WALL
#
#
#    This run was terminated on:  16:32:23  18Aug2020
#
# =------------------------------------------------------------------------------=
#    JOB DONE.
# =------------------------------------------------------------------------------=

# %%
# prints the list of new or modified files
print(relax.files)
# Out:
# ./outdir/graphene.xml
# ./outdir/graphene.save/C.pbe-n-kjpaw_psl.1.0.0.UPF
# ./outdir/graphene.save/wfc1.dat
# ./outdir/graphene.save/wfc8.dat
# ./outdir/graphene.save/wfc6.dat
# ./outdir/graphene.save/wfc10.dat
# ./outdir/graphene.save/wfc17.dat
# ./outdir/graphene.save/wfc3.dat
# ./outdir/graphene.save/wfc12.dat
# ./outdir/graphene.save/wfc4.dat
# ./outdir/graphene.save/data-file-schema.xml
# ./outdir/graphene.save/wfc7.dat
# ./outdir/graphene.save/wfc15.dat
# ./outdir/graphene.save/wfc2.dat
# ./outdir/graphene.save/wfc9.dat
# ./outdir/graphene.save/wfc11.dat
# ./outdir/graphene.save/wfc19.dat
# ./outdir/graphene.save/paw.txt
# ./outdir/graphene.save/wfc18.dat
# ./outdir/graphene.save/wfc5.dat
# ./outdir/graphene.save/wfc13.dat
# ./outdir/graphene.save/charge-density.dat
# ./outdir/graphene.save/wfc16.dat
# ./outdir/graphene.save/wfc14.dat

# %%
# Extract final coordinates to compare with the input file
#
# In this case the input file was already ok, so we don't need to change it.

id0 = relax.out.find('Begin final coordinates')
id1 = relax.out.find('End final coordinates') # 21 characters
print(relax.out[id0:id1+21])
# Out:
# Begin final coordinates
#      new unit-cell volume =    710.60042 a.u.^3 (   105.30012 Ang^3 )
#      density =      0.37881 g/cm^3
#
# CELL_PARAMETERS (alat=  4.64872629)
#    1.002302945   0.000000000   0.000000000
#   -0.501151472   0.868019813   0.000000000
#    0.000000000   0.000000000   8.130081301
#
# ATOMIC_POSITIONS (crystal)
# C        0.000000000   0.000000000   0.250000000
# C        0.333333333   0.666666667   0.250000000
# End final coordinates

# %% [markdown]
# ##  2 - Self-consistent calculation
#
# In this case we use the same input file from the relaxation because the lattice parameters were already fine. Therefore it is sufficient to change the calculation parameter from *vc-relax* to *scf*.
#
# To keep it all stored in different objects, here we initialize a new NAQUEI object.

# %%
# replace 'vc-relax' with 'scf'
scf_in = relax_in.replace('vc-relax', 'scf', 1)
# print(scf_in) # to see the input

# %%
# initializes the object and runs the code
scf = queiju(scf_in)
print("It took ", scf.run("pw.x"), " seconds")
# Out:
# It took  10.082718066871166  seconds

# %%
# prints the full output file
print(scf.out)
# if you want to save the output to a file, run
#scf.saveoutput('scf.out')
# Out:
#      Program PWSCF v.6.3 starts on 18Aug2020 at 16:33:25
#
#      This program is part of the open-source Quantum ESPRESSO suite
#      for quantum simulation of materials; please cite
#          "P. Giannozzi et al., J. Phys.:Condens. Matter 21 395502 (2009);
#          "P. Giannozzi et al., J. Phys.:Condens. Matter 29 465901 (2017);
#           URL http://www.quantum-espresso.org",
#      in publications or presentations arising from this work. More details at
#      http://www.quantum-espresso.org/quote
#
#      Parallel version (MPI), running on     1 processors
#
#      MPI processes distributed on     1 nodes
#      Waiting for input...
#      Reading input from standard input
# Warning: card &IONS ignored
# Warning: card / ignored
# Warning: card &CELL ignored
# Warning: card     CELL_DOFREE = '2DXY' ignored
# Warning: card / ignored
#
#      Current dimensions of program PWSCF are:
#      Max number of different atomic species (ntypx) = 10
#      Max number of k-points (npk) =  40000
#      Max angular momentum in pseudopotentials (lmaxx) =  3
#                file C.pbe-n-kjpaw_psl.1.0.0.UPF: wavefunction(s)  2S 2P renormalized
#
#      Subspace diagonalization in iterative solution of the eigenvalue problem:
#      a serial algorithm will be used
#
#
#      G-vector sticks info
#      --------------------
#      sticks:   dense  smooth     PW     G-vecs:    dense   smooth      PW
#      Sum         595     241     85                95599    24261    4575
#
#
#
#      bravais-lattice index     =            4
#      lattice parameter (alat)  =       4.6487  a.u.
#      unit-cell volume          =     707.3387 (a.u.)^3
#      number of atoms/cell      =            2
#      number of atomic types    =            1
#      number of electrons       =         8.00
#      number of Kohn-Sham states=            8
#      kinetic-energy cutoff     =      40.0000  Ry
#      charge density cutoff     =     400.0000  Ry
#      convergence threshold     =      1.0E-08
#      mixing beta               =       0.3000
#      number of iterations used =            8  plain     mixing
#      Exchange-correlation      = SLA PW PBX PBC ( 1  4  3  4 0 0)
#
#      celldm(1)=   4.648726  celldm(2)=   0.000000  celldm(3)=   8.130081
#      celldm(4)=   0.000000  celldm(5)=   0.000000  celldm(6)=   0.000000
#
#      crystal axes: (cart. coord. in units of alat)
#                a(1) = (   1.000000   0.000000   0.000000 )
#                a(2) = (  -0.500000   0.866025   0.000000 )
#                a(3) = (   0.000000   0.000000   8.130081 )
#
#      reciprocal axes: (cart. coord. in units 2 pi/alat)
#                b(1) = (  1.000000  0.577350 -0.000000 )
#                b(2) = (  0.000000  1.154701  0.000000 )
#                b(3) = (  0.000000 -0.000000  0.123000 )
#
#
#      PseudoPot. # 1 for C  read from file:
#      /home/gerson/pseudo/C.pbe-n-kjpaw_psl.1.0.0.UPF
#      MD5 check sum: 5f16ad9a65e90284d1d834d4ab3b0f7d
#      Pseudo is Projector augmented-wave + core cor, Zval =  4.0
#      Generated using "atomic" code by A. Dal Corso v.6.3
#      Shape of augmentation charge: PSQ
#      Using radial grid of 1073 points,  4 beta functions with:
#                 l(1) =   0
#                 l(2) =   0
#                 l(3) =   1
#                 l(4) =   1
#      Q(r) pseudized with 0 coefficients
#
#
#      atomic species   valence    mass     pseudopotential
#         C              4.00    12.01070     C ( 1.00)
#
#      12 Sym. Ops. (no inversion) found ( 6 have fractional translation)
#           (note: 12 additional sym.ops. were found but ignored
#            their fractional translations are incommensurate with FFT grid)
#
#
#    Cartesian axes
#
#      site n.     atom                  positions (alat units)
#          1           C   tau(   1) = (   0.0000000   0.0000000   2.0325203  )
#          2           C   tau(   2) = (  -0.0000000   0.5773503   2.0325203  )
#
#      number of k points=    19  Marzari-Vanderbilt smearing, width (Ry)=  0.0001
#                        cart. coord. in units 2pi/alat
#         k(    1) = (   0.0000000   0.0000000   0.0000000), wk =   0.0138889
#         k(    2) = (   0.0000000   0.0962250   0.0000000), wk =   0.0833333
#         k(    3) = (   0.0000000   0.1924501   0.0000000), wk =   0.0833333
#         k(    4) = (   0.0000000   0.2886751   0.0000000), wk =   0.0833333
#         k(    5) = (   0.0000000   0.3849002   0.0000000), wk =   0.0833333
#         k(    6) = (   0.0000000   0.4811252   0.0000000), wk =   0.0833333
#         k(    7) = (   0.0000000  -0.5773503   0.0000000), wk =   0.0416667
#         k(    8) = (   0.0833333   0.1443376   0.0000000), wk =   0.0833333
#         k(    9) = (   0.0833333   0.2405626   0.0000000), wk =   0.1666667
#         k(   10) = (   0.0833333   0.3367877   0.0000000), wk =   0.1666667
#         k(   11) = (   0.0833333   0.4330127   0.0000000), wk =   0.1666667
#         k(   12) = (   0.0833333   0.5292377   0.0000000), wk =   0.1666667
#         k(   13) = (   0.1666667   0.2886751   0.0000000), wk =   0.0833333
#         k(   14) = (   0.1666667   0.3849002   0.0000000), wk =   0.1666667
#         k(   15) = (   0.1666667   0.4811252   0.0000000), wk =   0.1666667
#         k(   16) = (   0.1666667   0.5773503   0.0000000), wk =   0.0833333
#         k(   17) = (   0.2500000   0.4330127   0.0000000), wk =   0.0833333
#         k(   18) = (   0.2500000   0.5292377   0.0000000), wk =   0.1666667
#         k(   19) = (   0.3333333   0.5773503   0.0000000), wk =   0.0277778
#
#      Dense  grid:    95599 G-vectors     FFT dimensions: (  30,  30, 243)
#
#      Smooth grid:    24261 G-vectors     FFT dimensions: (  20,  20, 160)
#
#      Estimated max dynamical RAM per process >     128.32 MB
#  ----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D
#   The code is running with the 2D cutoff
#   Please refer to:
#   Sohier, T., Calandra, M., & Mauri, F. (2017),
#   Density functional perturbation theory for gated two-dimensional heterostructures:
#   Theoretical developments and application to flexural phonons in graphene.
#   Physical Review B, 96(7), 75448. https://doi.org/10.1103/PhysRevB.96.075448
#  ----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D----2D
#
#      Check: negative/imaginary core charge=   -0.000002    0.000000
#
#      Initial potential from superposition of free atoms
#      Check: negative starting charge=   -0.000106
#
#      starting charge    7.99992, renormalised to    8.00000
#
#      negative rho (up, down):  1.058E-04 0.000E+00
#      Starting wfcs are    8 randomized atomic wfcs
#      Checking if some PAW data can be deallocated...
#
#      total cpu time spent up to now is        0.9 secs
#
#      Self-consistent Calculation
#
#      iteration #  1     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  1.00E-02,  avg # of iterations =  5.3
#
#      negative rho (up, down):  1.029E-04 0.000E+00
#
#      total cpu time spent up to now is        2.1 secs
#
#      total energy              =     -36.90806172 Ry
#      Harris-Foulkes estimate   =     -36.97874779 Ry
#      estimated scf accuracy    <       0.20471188 Ry
#
#      iteration #  2     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  2.56E-03,  avg # of iterations =  1.0
#
#      negative rho (up, down):  2.666E-04 0.000E+00
#
#      total cpu time spent up to now is        3.0 secs
#
#      total energy              =     -36.87338375 Ry
#      Harris-Foulkes estimate   =     -36.91398442 Ry
#      estimated scf accuracy    <       0.06925352 Ry
#
#      iteration #  3     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  8.66E-04,  avg # of iterations =  6.8
#
#      negative rho (up, down):  2.515E-04 0.000E+00
#
#      total cpu time spent up to now is        4.2 secs
#
#      total energy              =     -36.88642351 Ry
#      Harris-Foulkes estimate   =     -36.88604563 Ry
#      estimated scf accuracy    <       0.00156863 Ry
#
#      iteration #  4     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  1.96E-05,  avg # of iterations =  4.6
#
#      negative rho (up, down):  2.199E-04 0.000E+00
#
#      total cpu time spent up to now is        5.4 secs
#
#      total energy              =     -36.88506318 Ry
#      Harris-Foulkes estimate   =     -36.88790956 Ry
#      estimated scf accuracy    <       0.00437517 Ry
#
#      iteration #  5     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  1.96E-05,  avg # of iterations =  2.9
#
#      negative rho (up, down):  1.781E-04 0.000E+00
#
#      total cpu time spent up to now is        6.4 secs
#
#      total energy              =     -36.88582227 Ry
#      Harris-Foulkes estimate   =     -36.88582238 Ry
#      estimated scf accuracy    <       0.00000230 Ry
#
#      iteration #  6     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  2.87E-08,  avg # of iterations =  3.3
#
#      negative rho (up, down):  1.544E-04 0.000E+00
#
#      total cpu time spent up to now is        7.5 secs
#
#      total energy              =     -36.88582381 Ry
#      Harris-Foulkes estimate   =     -36.88582354 Ry
#      estimated scf accuracy    <       0.00000049 Ry
#
#      iteration #  7     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  6.12E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.409E-04 0.000E+00
#
#      total cpu time spent up to now is        8.4 secs
#
#      total energy              =     -36.88582368 Ry
#      Harris-Foulkes estimate   =     -36.88582386 Ry
#      estimated scf accuracy    <       0.00000032 Ry
#
#      iteration #  8     ecut=    40.00 Ry     beta= 0.30
#      Davidson diagonalization with overlap
#      ethr =  3.95E-09,  avg # of iterations =  2.0
#
#      negative rho (up, down):  1.256E-04 0.000E+00
#
#      total cpu time spent up to now is        9.2 secs
#
#      End of self-consistent calculation
#
#           k = 0.0000 0.0000 0.0000 (  3053 PWs)   bands (ev):
#
#    -23.8079 -11.8918  -7.2698  -7.2698  -1.0362  -0.3613   0.4085   0.8961
#
#           k = 0.0000 0.0962 0.0000 (  3034 PWs)   bands (ev):
#
#    -23.6433 -11.6947  -7.9226  -7.6109  -0.8120  -0.1338   0.6364   1.1228
#
#           k = 0.0000 0.1925 0.0000 (  3042 PWs)   bands (ev):
#
#    -23.1511 -11.1084  -9.5671  -8.4098  -0.1393   0.5478   1.3200   1.8014
#
#           k = 0.0000 0.2887 0.0000 (  3030 PWs)   bands (ev):
#
#    -22.3372 -11.6743 -10.1524  -9.2963   0.9797   1.6731   2.4579   2.8620
#
#           k = 0.0000 0.3849 0.0000 (  3024 PWs)   bands (ev):
#
#    -21.2136 -13.8873 -10.0352  -8.8769   0.7206   2.5347   3.2851   3.5667
#
#           k = 0.0000 0.4811 0.0000 (  3034 PWs)   bands (ev):
#
#    -19.8110 -15.9979 -10.5113  -7.4455  -1.4291   3.3170   4.5560   5.3058
#
#           k = 0.0000-0.5774 0.0000 (  3036 PWs)   bands (ev):
#
#    -18.5350 -17.5179 -10.6749  -6.5952  -2.5351   3.2392   6.8777   7.0225
#
#           k = 0.0833 0.1443 0.0000 (  3043 PWs)   bands (ev):
#
#    -23.3149 -11.3029  -8.9602  -8.2939  -0.3633   0.3209   1.0923   1.5756
#
#           k = 0.0833 0.2406 0.0000 (  3029 PWs)   bands (ev):
#
#    -22.6618 -10.6767 -10.5305  -9.2991   0.5333   1.2276   2.0039   2.4773
#
#           k = 0.0833 0.3368 0.0000 (  3026 PWs)   bands (ev):
#
#    -21.6930 -12.7589 -10.1913  -9.4083   1.7385   1.8740   2.6068   3.3684
#
#           k = 0.0833 0.4330 0.0000 (  3023 PWs)   bands (ev):
#
#    -20.4270 -14.8917 -10.8302  -8.0205  -0.4746   3.6358   4.1698   4.3958
#
#           k = 0.0833 0.5292 0.0000 (  3021 PWs)   bands (ev):
#
#    -18.9386 -16.8445 -11.1606  -6.7029  -2.2559   3.9798   5.8624   6.6034
#
#           k = 0.1667 0.2887 0.0000 (  3017 PWs)   bands (ev):
#
#    -21.8538 -12.0104 -10.6709  -9.5880   1.6526   2.2022   2.3564   3.1437
#
#           k = 0.1667 0.3849 0.0000 (  3024 PWs)   bands (ev):
#
#    -20.7412 -13.7457 -11.7328  -8.3278   0.2412   3.2107   3.9211   4.7359
#
#           k = 0.1667 0.4811 0.0000 (  3015 PWs)   bands (ev):
#
#    -19.3586 -15.6668 -12.3109  -6.8923  -1.6842   5.1834   5.8622   5.8971
#
#           k = 0.1667 0.5774 0.0000 (  2996 PWs)   bands (ev):
#
#    -18.1126 -17.1146 -12.4964  -5.9935  -2.7602   5.7943   7.4477   7.6359
#
#           k = 0.2500 0.4330 0.0000 (  3009 PWs)   bands (ev):
#
#    -19.5073 -14.7816 -13.2272  -6.9771  -1.3829   4.9710   5.5857   6.5508
#
#           k = 0.2500 0.5292 0.0000 (  2995 PWs)   bands (ev):
#
#    -18.0768 -16.2120 -13.9375  -5.5826  -2.9131   6.6635   7.0843   8.0624
#
#           k = 0.3333 0.5774 0.0000 (  2967 PWs)   bands (ev):
#
#    -16.8517 -16.8517 -14.8453  -4.2183  -4.2183   6.4079   8.7054   8.7054
#
#      the Fermi energy is    -4.2181 ev
#
# !    total energy              =     -36.88582372 Ry
#      Harris-Foulkes estimate   =     -36.88582372 Ry
#      estimated scf accuracy    <          1.8E-09 Ry
#
#      total all-electron energy =      -152.414018 Ry
#
#      The total energy is the sum of the following terms:
#
#      one-electron contribution =    -359.09323334 Ry
#      hartree contribution      =     180.42965906 Ry
#      xc contribution           =      -9.28434657 Ry
#      ewald contribution        =     163.39636289 Ry
#      one-center paw contrib.   =     -12.33426486 Ry
#      smearing contrib. (-TS)   =      -0.00000091 Ry
#
#      convergence has been achieved in   8 iterations
#
#      Writing output data file graphene.save/
#
#      init_run     :      2.18s CPU      0.69s WALL (       1 calls)
#      electrons    :     46.97s CPU      8.37s WALL (       1 calls)
#
#      Called by init_run:
#      wfcinit      :      1.74s CPU      0.25s WALL (       1 calls)
#      potinit      :      0.20s CPU      0.20s WALL (       1 calls)
#      hinit0       :      0.18s CPU      0.18s WALL (       1 calls)
#
#      Called by electrons:
#      c_bands      :     34.72s CPU      5.06s WALL (       8 calls)
#      sum_band     :      9.06s CPU      1.65s WALL (       8 calls)
#      v_of_rho     :      0.97s CPU      0.80s WALL (       9 calls)
#      newd         :      0.45s CPU      0.25s WALL (       9 calls)
#      PAW_pot      :      0.52s CPU      0.52s WALL (       9 calls)
#      mix_rho      :      1.14s CPU      0.18s WALL (       8 calls)
#
#      Called by c_bands:
#      init_us_2    :      1.60s CPU      0.24s WALL (     323 calls)
#      cegterg      :     31.83s CPU      4.62s WALL (     152 calls)
#
#      Called by sum_band:
#      sum_band:bec :      0.00s CPU      0.00s WALL (     152 calls)
#      addusdens    :      2.91s CPU      0.65s WALL (       8 calls)
#
#      Called by *egterg:
#      h_psi        :     29.16s CPU      4.25s WALL (     701 calls)
#      s_psi        :      0.17s CPU      0.02s WALL (     701 calls)
#      g_psi        :      0.88s CPU      0.13s WALL (     530 calls)
#      cdiaghg      :      0.97s CPU      0.14s WALL (     682 calls)
#
#      Called by h_psi:
#      h_psi:pot    :     28.79s CPU      4.20s WALL (     701 calls)
#      h_psi:calbec :      0.58s CPU      0.08s WALL (     701 calls)
#      vloc_psi     :     27.96s CPU      4.08s WALL (     701 calls)
#      add_vuspsi   :      0.22s CPU      0.03s WALL (     701 calls)
#
#      General routines
#      calbec       :      0.70s CPU      0.10s WALL (     853 calls)
#      fft          :      1.81s CPU      0.60s WALL (     116 calls)
#      ffts         :      0.01s CPU      0.01s WALL (      17 calls)
#      fftw         :     23.34s CPU      3.46s WALL (    8586 calls)
#      interpolate  :      0.04s CPU      0.04s WALL (       9 calls)
#
#      Parallel routines
#
#      PWSCF        :    49.58s CPU         9.29s WALL
#
#
#    This run was terminated on:  16:33:34  18Aug2020
#
# =------------------------------------------------------------------------------=
#    JOB DONE.
# =------------------------------------------------------------------------------=

# %%
# prints the list of new or modified files
print(scf.files)
# Out:
# ./outdir/graphene.xml
# ./outdir/graphene.save/C.pbe-n-kjpaw_psl.1.0.0.UPF
# ./outdir/graphene.save/wfc1.dat
# ./outdir/graphene.save/wfc8.dat
# ./outdir/graphene.save/wfc6.dat
# ./outdir/graphene.save/wfc10.dat
# ./outdir/graphene.save/wfc17.dat
# ./outdir/graphene.save/wfc3.dat
# ./outdir/graphene.save/wfc12.dat
# ./outdir/graphene.save/wfc4.dat
# ./outdir/graphene.save/data-file-schema.xml
# ./outdir/graphene.save/wfc7.dat
# ./outdir/graphene.save/wfc15.dat
# ./outdir/graphene.save/wfc2.dat
# ./outdir/graphene.save/wfc9.dat
# ./outdir/graphene.save/wfc11.dat
# ./outdir/graphene.save/wfc19.dat
# ./outdir/graphene.save/paw.txt
# ./outdir/graphene.save/wfc18.dat
# ./outdir/graphene.save/wfc5.dat
# ./outdir/graphene.save/wfc13.dat
# ./outdir/graphene.save/charge-density.dat
# ./outdir/graphene.save/wfc16.dat
# ./outdir/graphene.save/wfc14.dat

# %% [markdown]
# ## Bands
#
# To prepare the bands input, we use the scf input above and
#
# - replace the calculation from scf to bands
# - remove the K_POINTS section to replace it with a k-path
# - attach the k-path and bands parameters to the input
# - run pw.x and then bands.x

# %%
bands_in = scf_in.replace('scf', 'bands', 1) # replace scf with bands
id0 = bands_in.find('K_POINTS') # find where K_POINTS start
bands_in = bands_in[:id0] # remove from K_POINTS to the end
bands_in += """K_POINTS crystal_b
4
+0.0000000000 0.000000000 0.000000000 30 ! G
-0.3333333333 0.666666667 0.000000000 30 ! K
+0.0000000000 0.500000000 0.000000000 30 ! M
+0.0000000000 0.000000000 0.000000000 30 ! G
&bands
outdir = './outdir'
prefix = 'graphene'
filband = 'graphene.bands.dat'
/
"""
#print(bands_in)

# %%
# initializes the object and runs the code
bands = queiju(bands_in)
plot = queiju(bands_in)
# run both objects
print("It took ", bands.run("pw.x"), " seconds")
print("It took ", plot.run("bands.x"), " seconds")
# Out:
# It took  20.829707358032465  seconds
# It took  15.834395329002291  seconds

# %%
#print(bands.files)
print(plot.files)
# Out:
# ./graphene.bands.dat.rap
# ./graphene.bands.dat
# ./outdir/graphene.wfc1
# ./graphene.bands.dat.gnu

# %% [markdown]
# ## Plot bands

# %%
# TO DO: extract filename automatically
data = np.loadtxt('graphene.bands.dat.gnu')
data.shape
# Out:
# (728, 2)

# %%
# TO DO: extract the Fermi energy automatically from the scf output
id0 = scf.out.find('the Fermi energy is')
print(scf.out[id0:(id0+33)])
fermi = -4.2181
# Out:
# the Fermi energy is    -4.2181 ev

# %%
# TO DO: extract k-points automatically
kpath = [data[ 0,0], data[30,0], data[60,0], data[90,0]]
klabel = [R'$\Gamma$', R'$K$', R'$M$', R'$\Gamma$']

# %%
plt.figure(figsize=(6,5))
plt.rcParams.update({'font.size': 18})
plt.clf()

plt.scatter(data[:,0], data[:,1]-fermi)
plt.xticks(kpath, klabel)
plt.ylim(-5,5)
plt.ylabel(R"Energy [meV]")
plt.grid()
plt.show()
